# %%
from Ornstein_Uhlenbeck import Ornstein_Uhlenbeck
from scipy.stats import norm
from statsmodels.tsa.stattools import adfuller
import backtrader as bt
import datetime
import numpy as np
import pandas as pd
import warnings

# %%
np.seterr(all="ignore")
warnings.simplefilter('ignore', pd.errors.PerformanceWarning)

# %%
stock_list = pd.read_csv('data/stock_list.csv')['Symbol']
obs = 252 # number of observations used by the model
cash = 100000000
commission = 0.004
stock_dict = {}
for stock in stock_list:
    stock_dict[stock] = pd.read_csv('data/stock/{}.csv'.format(stock), index_col='Date', parse_dates=['Date'])
    stock_dict[stock] = stock_dict[stock][stock_dict[stock].index < datetime.datetime(2019, 1, 1)].dropna()

# %%
class PandasData(bt.feeds.PandasData):
    lines = ('open', 'high', 'low', 'close', 'volume')
    params = (('datetime', None),
              ('open', 0),
              ('high', 1),
              ('low', 2),
              ('close', 3),
              ('adjclose', 4),
              ('volume', 5))

# %%
def get_hurst_exponent(time_series, max_lag=20):
    lags = range(2, max_lag)

    tau = [np.std(np.subtract(time_series[lag:], time_series[:-lag])) for lag in lags]
    
    reg = np.polyfit(np.log(lags), np.log(tau), 1)

    return reg[0]

# %%
perf_df = pd.DataFrame(columns=['Start Date', 'End Date', 'a', 'b', 'Spread Return', 'Position', 'Correlation', 'Hurst Exponent', 'ADF t-statistic', 'ADF p-value', 'mu', 'theta', 'sigma2'])

# %%
# computation setting
skip_list = []
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.obs = obs
        self.n = 0 # number of days
        self.max_n = stock_dict[stock_list[0]].shape[0]
        self.pos = 0 # initial position
        self.leverage = 3
        self.max_buy_portion = 0.9
        
        # stocks selection
        self.req_corr = 0.7
        self.req_adf = 0.01
        self.req_hurst = 0.5
        
        # model settings
        self.model = None
        self.model_list = None
        self.idx_list = None
        self.a, self.b = None, None # index of Sta and Stb
        self.z = norm.ppf(0.99)

    def signal_generation(self):
        if self.model_list is None or self.n >= self.max_n - 1:
            return 0
        
        if self.model is not None:
            self.Xt = self.model.alpha * self.Sta[-1] - self.model.beta * self.Stb[-1]
    
            if self.pos == 1:
                if self.Xt >= self.EX:
                    return 0
                else:
                    return 1
            elif self.pos == -1:
                if self.Xt <= self.EX:
                    return 0
                else:
                    return -1
        else:
            for i, model in enumerate(self.model_list):
                self.Sta = np.array(self.datas[self.idx_list[i][0]].close.get(size=self.obs))
                self.Stb = np.array(self.datas[self.idx_list[i][1]].close.get(size=self.obs))
                self.Xt = model.alpha * self.Sta[-1] - model.beta * self.Stb[-1]
                self.update_statistics(model)
                if self.Xt > self.EX + self.z * np.sqrt(self.VarX):
                    self.model = model
                    self.a, self.b = self.idx_list[i][0], self.idx_list[i][1]
                    self.corr = self.corr_list[i]
                    self.adf = self.adf_list[i]
                    self.hurst = self.hurst_list[i]
                    return -1
                elif self.Xt < self.EX - self.z * np.sqrt(self.VarX):
                    self.model = model
                    self.a, self.b = self.idx_list[i][0], self.idx_list[i][1]
                    self.corr = self.corr_list[i]
                    self.adf = self.adf_list[i]
                    self.hurst = self.hurst_list[i]
                    return 1
            skip_list.append(self.data.datetime.date())
            return 0
    
    def update_statistics(self, model):
        self.EX = model.mu
        self.VarX = model.sigma2 / (2 * model.theta)
    
    def renew_model_list(self):
        stock_df = pd.DataFrame()
        for i, stock in enumerate(stock_list):
            stock_df[i] = np.array(self.datas[i].close.get(size=self.obs))
        corr = stock_df.pct_change().corr()
        model_list = []
        idx_list = []
        corr_list = []
        hurst_list = []
        adf_list = []
            
        for i in range(len(stock_list)):
            for j in range(i):
                if corr[i][j] > self.req_corr and len(perf_df[perf_df['a'].isin([i, j]) & perf_df['b'].isin([i, j])]) == 0: 
                    model1 = Ornstein_Uhlenbeck(stock_df[i].values, stock_df[j].values)
                    model2 = Ornstein_Uhlenbeck(stock_df[j].values, stock_df[i].values)
                    swap = 0
                    if model1.l is None and model2.l is None:
                        model = None
                    elif model1.l is None and model2.l is not None:
                        model = model2
                        swap = 1
                    elif model1.l is not None and model2.l is None:
                        model = model1
                    else:
                        if model1.l >= model2.l:
                            model = model1
                        else:
                            model = model2
                            swap = 1
                    
                    hurst = get_hurst_exponent(model.X)
                    adf = adfuller(model.X)
                    if hurst < self.req_hurst and adf[1] < self.req_adf:
                        model_list.append(model)
                        idx_list.append((i, j)) if swap == 0 else idx_list.append((j, i))
                        corr_list.append(corr[i][j])
                        hurst_list.append(hurst)
                        adf_list.append(adf)

        if len(model_list) > 0:
            self.model_list = [model_list[i] for i in range(len(model_list))]
            self.idx_list = [idx_list[i] for i in range(len(model_list))]
            self.corr_list = [corr_list[i] for i in range(len(model_list))]
            self.hurst_list = [hurst_list[i] for i in range(len(model_list))]
            self.adf_list = [adf_list[i] for i in range(len(model_list))]
        
    def close_positions(self): # to close all existing positions
        self.close(data=self.datas[self.a])
        self.close(data=self.datas[self.b])
    
    def start(self):
        self.last_day = self.data.datetime.date(-1)  # Get the last available date
        
    def next(self): 
        self.n += 1
        if self.n >= self.obs:
            if self.data.datetime.date() not in skip_list and self.model_list is None:
                self.renew_model_list()
            if self.model is not None:
                self.Sta = np.array(self.datas[self.a].close.get(size=self.obs))
                self.Stb = np.array(self.datas[self.b].close.get(size=self.obs))
            
        self.signal = self.signal_generation()
        
        if self.signal != 0 and self.pos == 0:
            print('Number of Pairs: {} | Best Pair\'s Correlation: {:.2f} | Best Pair\'s Hurst Exponent: {:.2f} | Best Pair\'s p-value: {:.2f}'.format(len(self.model_list), self.corr, self.hurst, self.adf[1]))
    
        if self.signal == 1:
            if self.pos == 0:
                k = self.leverage / (self.Sta[-1] * self.model.alpha + self.model.beta * self.Stb[-1])
                k = np.min([k, 1 / (self.model.alpha * self.Sta[-1])])
                self.sell(data=self.datas[self.b], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.beta * k)
                self.buy(data=self.datas[self.a], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.alpha * k)
                self.Xs = self.Xt
                self.startdate = self.data.datetime.date()
                print("{}: Long {} and short {} when Xt = {:.2f}".format(self.data.datetime.date(), stock_list.loc[self.a], stock_list.loc[self.b], self.Xt))
                
        elif self.signal == -1:
            if self.pos == 0:
                k = self.leverage / (self.Sta[-1] * self.model.alpha + self.model.beta * self.Stb[-1])
                k = np.min([k, 1 / (self.model.beta * self.Stb[-1])])
                self.sell(data=self.datas[self.a], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.alpha * k)
                self.buy(data=self.datas[self.b], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.beta * k)
                self.Xs = self.Xt
                self.startdate = self.data.datetime.date()
                print("{}: Short {} and long {} when Xt = {:.2f}".format(self.data.datetime.date(), stock_list.loc[self.a], stock_list.loc[self.b], self.Xt))
                
        else: # self.signal == 0
            if self.pos != 0:
                self.close_positions()
                perf_df.loc[len(perf_df)] = [self.startdate, self.data.datetime.date(), self.a, self.b, np.log(self.Xt / self.Xs) * self.pos, self.pos, self.corr, self.hurst, self.adf[0], self.adf[1], self.model.mu, self.model.theta, self.model.sigma2]
                self.model = None
                print("{}: Close pair when Xt = {:.2f}".format(self.data.datetime.date(), self.Xt))
                
        self.pos = self.signal
        
        if self.n >= self.obs and self.pos == 0:
                self.model_list = None

# %%
i = 0
complete = 0
while complete == 0:
    print('i = {}'.format(i))
    # backtest settings
    cerebro = bt.Cerebro()
    
    data_feed_dict = {}
    for stock in stock_list:
        data_feed_dict[stock] = PandasData(dataname=stock_dict[stock], name=stock)
        cerebro.adddata(data_feed_dict[stock])
    
    cerebro.addstrategy(MyStrategy)
    cerebro.broker.setcash(cash)
    cerebro.broker.setcommission(commission=commission)
    # Run the backtest
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    results = cerebro.run()
    pyfolio_analyzer = results[0].analyzers.pyfolio
    returns, positions, transactions, gross_lev = pyfolio_analyzer.get_pf_items()
    if transactions.shape[0] == 0:
        complete = 1
    i += 1
# Out:
# i = 0
# Number of Pairs: 13 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2015-01-07: Long C and short MS when Xt = 0.25
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 19 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-03-04: Short IVZ and long PFG when Xt = 0.36
# 2015-06-03: Close pair when Xt = 0.30
# Number of Pairs: 26 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2015-06-05: Long BXP and short EQR when Xt = 0.19
# 2016-04-13: Close pair when Xt = 0.22
# Number of Pairs: 43 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.00
# 2016-04-18: Short KEY and long MS when Xt = 0.30
# 2016-06-27: Close pair when Xt = 0.24
# Number of Pairs: 36 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.01
# 2016-06-28: Short HON and long OMC when Xt = 0.31
# 2016-09-01: Close pair when Xt = 0.25
# Number of Pairs: 37 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-09-15: Long XEL and short NEE when Xt = 0.17
# 2016-09-26: Close pair when Xt = 0.20
# Number of Pairs: 47 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.00
# 2016-09-28: Long BLK and short CPAY when Xt = 0.34
# 2016-11-07: Close pair when Xt = 0.46
# Number of Pairs: 39 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2016-11-08: Short AEE and long CMS when Xt = 0.17
# 2018-12-28: Close pair when Xt = 0.31
# i = 1
# Number of Pairs: 23 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-01-13: Long C and short STT when Xt = 0.21
# 2015-02-26: Close pair when Xt = 0.26
# Number of Pairs: 14 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-03-10: Long D and short AEE when Xt = 0.26
# 2015-04-15: Close pair when Xt = 0.30
# Number of Pairs: 32 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2015-04-30: Short MCK and long CAH when Xt = 0.32
# 2015-08-07: Close pair when Xt = 0.26
# Number of Pairs: 16 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-08-12: Long TFC and short SCHW when Xt = 0.51
# 2016-06-30: Close pair when Xt = 0.55
# Number of Pairs: 46 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2016-07-06: Short HON and long AVY when Xt = 0.43
# 2016-07-26: Close pair when Xt = 0.37
# Number of Pairs: 46 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.00
# 2016-07-28: Long MET and short STT when Xt = 0.16
# 2016-11-10: Close pair when Xt = 0.24
# Number of Pairs: 32 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-11-11: Short MAR and long HST when Xt = 0.41
# 2018-12-28: Close pair when Xt = 0.86
# i = 2
# Number of Pairs: 15 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.00
# 2015-01-27: Long JPM and short RJF when Xt = 0.33
# 2015-02-26: Close pair when Xt = 0.38
# Number of Pairs: 12 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-03-16: Long XEL and short CMS when Xt = 0.13
# 2015-08-06: Close pair when Xt = 0.16
# Number of Pairs: 20 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-08-17: Short D and long DTE when Xt = 0.23
# 2015-08-31: Close pair when Xt = 0.20
# Number of Pairs: 27 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2015-09-10: Long D and short ED when Xt = 0.20
# 2018-12-28: Close pair when Xt = 0.10
# i = 3
# Number of Pairs: 17 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-01-30: Long SO and short CMS when Xt = 0.29
# 2018-12-28: Close pair when Xt = -0.16
# i = 4
# Number of Pairs: 13 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.01
# 2015-02-06: Long SO and short ES when Xt = 0.25
# 2016-07-06: Close pair when Xt = 0.29
# Number of Pairs: 43 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.01
# 2016-07-07: Long NTRS and short CMA when Xt = 0.20
# 2018-12-28: Close pair when Xt = 0.02
# i = 5
# Number of Pairs: 22 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-02-18: Short NEE and long ATO when Xt = 0.31
# 2015-03-03: Close pair when Xt = 0.26
# Number of Pairs: 19 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-03-24: Long CB and short HIG when Xt = 0.40
# 2015-12-21: Close pair when Xt = 0.44
# Number of Pairs: 47 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2016-01-04: Long GPC and short ITW when Xt = 0.15
# 2016-02-19: Close pair when Xt = 0.20
# Number of Pairs: 34 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.01
# 2016-02-26: Short BRO and long USB when Xt = 0.51
# 2018-12-28: Close pair when Xt = 1.10
# i = 6
# Number of Pairs: 24 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2015-03-30: Short FRT and long EQR when Xt = 0.32
# 2015-04-16: Close pair when Xt = 0.27
# Number of Pairs: 24 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.48 | Best Pair's p-value: 0.01
# 2015-05-04: Long FRT and short ARE when Xt = 0.20
# 2015-09-21: Close pair when Xt = 0.25
# Number of Pairs: 32 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.01
# 2015-09-28: Long ITW and short MMM when Xt = 0.18
# 2015-11-24: Close pair when Xt = 0.22
# Number of Pairs: 34 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-12-07: Long C and short SCHW when Xt = 0.28
# 2017-07-03: Close pair when Xt = 0.33
# Number of Pairs: 5 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2017-07-11: Short DHI and long PHM when Xt = 0.27
# 2017-08-18: Close pair when Xt = 0.22
# Number of Pairs: 13 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2017-08-24: Long HBAN and short RF when Xt = 0.20
# 2017-09-12: Close pair when Xt = 0.27
# Number of Pairs: 18 | Best Pair's Correlation: 0.94 | Best Pair's Hurst Exponent: 0.15 | Best Pair's p-value: 0.00
# 2017-10-23: Short NWSA and long NWS when Xt = 0.02
# 2017-11-10: Close pair when Xt = 0.01
# Number of Pairs: 7 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2017-12-06: Short PNC and long MS when Xt = 0.39
# 2018-04-17: Close pair when Xt = 0.35
# Number of Pairs: 12 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2018-05-02: Long GS and short MS when Xt = 0.17
# 2018-08-20: Close pair when Xt = 0.24
# Number of Pairs: 7 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2018-10-09: Short CPT and long MAA when Xt = 0.23
# 2018-10-29: Close pair when Xt = 0.20
# Number of Pairs: 11 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.01
# 2018-10-30: Short AON and long AJG when Xt = 0.28
# 2018-12-19: Close pair when Xt = 0.22
# i = 7
# Number of Pairs: 23 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2015-04-07: Long WFC and short HBAN when Xt = 0.39
# 2015-04-27: Close pair when Xt = 0.44
# Number of Pairs: 25 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2015-05-06: Long BXP and short ARE when Xt = 0.22
# 2016-01-26: Close pair when Xt = 0.26
# Number of Pairs: 62 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.01
# 2016-01-27: Long HBAN and short C when Xt = 0.18
# 2016-02-26: Close pair when Xt = 0.27
# Number of Pairs: 33 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.01
# 2016-03-01: Long SO and short XEL when Xt = 0.23
# 2016-03-14: Close pair when Xt = 0.26
# Number of Pairs: 37 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2016-03-17: Short MAA and long PSA when Xt = 0.31
# 2016-04-14: Close pair when Xt = 0.26
# Number of Pairs: 34 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-04-19: Short NTRS and long PRU when Xt = 0.23
# 2016-07-14: Close pair when Xt = 0.19
# Number of Pairs: 40 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2016-07-29: Long ALL and short CINF when Xt = 0.32
# 2016-11-03: Close pair when Xt = 0.37
# Number of Pairs: 32 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.00
# 2016-11-04: Long AIG and short BAC when Xt = 0.35
# 2018-12-28: Close pair when Xt = -0.21
# i = 8
# Number of Pairs: 19 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.40 | Best Pair's p-value: 0.00
# 2015-06-10: Long PPL and short EXC when Xt = 0.34
# 2015-07-10: Close pair when Xt = 0.40
# Number of Pairs: 21 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-07-17: Short HON and long TXT when Xt = 0.52
# 2015-09-23: Close pair when Xt = 0.48
# Number of Pairs: 31 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.41 | Best Pair's p-value: 0.00
# 2015-09-28: Long D and short WEC when Xt = 0.25
# 2018-12-28: Close pair when Xt = 0.04
# i = 9
# Number of Pairs: 17 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2015-06-10: Short CINF and long TRV when Xt = 0.32
# 2018-12-28: Close pair when Xt = 0.70
# i = 10
# Number of Pairs: 31 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-10: Short TFC and long C when Xt = 0.36
# 2015-07-17: Close pair when Xt = 0.31
# Number of Pairs: 13 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-08-25: Long TFC and short GS when Xt = 0.27
# 2015-10-08: Close pair when Xt = 0.31
# Number of Pairs: 48 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.01
# 2015-10-09: Short FRT and long O when Xt = 0.34
# 2016-01-21: Close pair when Xt = 0.29
# Number of Pairs: 72 | Best Pair's Correlation: 0.88 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2016-01-22: Short WFC and long TFC when Xt = 0.22
# 2016-02-08: Close pair when Xt = 0.19
# Number of Pairs: 43 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2016-02-09: Short BRO and long WFC when Xt = 0.50
# 2018-12-28: Close pair when Xt = 1.21
# i = 11
# Number of Pairs: 30 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2015-09-30: Short ADP and long BLK when Xt = 0.51
# 2016-01-07: Close pair when Xt = 0.45
# Number of Pairs: 42 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.01
# 2016-01-08: Short AEP and long PCG when Xt = 0.20
# 2016-08-18: Close pair when Xt = 0.17
# Number of Pairs: 52 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2016-08-19: Short PCG and long NI when Xt = 0.42
# 2016-10-04: Close pair when Xt = 0.36
# Number of Pairs: 36 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2016-10-11: Long AEE and short PNW when Xt = 0.17
# 2016-11-04: Close pair when Xt = 0.21
# Number of Pairs: 33 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.49 | Best Pair's p-value: 0.01
# 2016-11-09: Short MTB and long AMP when Xt = 0.49
# 2017-11-09: Close pair when Xt = 0.39
# Number of Pairs: 9 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2018-01-19: Long CMS and short DTE when Xt = 0.13
# 2018-04-04: Close pair when Xt = 0.15
# Number of Pairs: 9 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2018-06-05: Long CCL and short NCLH when Xt = 0.39
# 2018-12-28: Close pair when Xt = 0.30
# i = 12
# Number of Pairs: 31 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.01
# 2015-10-02: Long D and short ES when Xt = 0.20
# 2016-11-29: Close pair when Xt = 0.24
# Number of Pairs: 22 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-12-07: Short TFC and long RJF when Xt = 0.41
# 2017-02-08: Close pair when Xt = 0.36
# Number of Pairs: 30 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.42 | Best Pair's p-value: 0.00
# 2017-02-10: Short EIX and long LNT when Xt = 0.31
# 2017-08-18: Close pair when Xt = 0.26
# Number of Pairs: 10 | Best Pair's Correlation: 0.89 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.01
# 2017-09-01: Short CMS and long ES when Xt = 0.09
# 2017-09-14: Close pair when Xt = 0.07
# Number of Pairs: 17 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.01
# 2017-10-25: Short WEC and long DTE when Xt = 0.14
# 2018-03-02: Close pair when Xt = 0.11
# Number of Pairs: 10 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2018-03-15: Short APD and long LIN when Xt = 0.36
# 2018-05-03: Close pair when Xt = 0.32
# Number of Pairs: 7 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.20 | Best Pair's p-value: 0.00
# 2018-06-15: Long DTE and short XEL when Xt = 0.12
# 2018-07-05: Close pair when Xt = 0.14
# Number of Pairs: 10 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2018-07-13: Short NTRS and long RF when Xt = 0.40
# 2018-08-16: Close pair when Xt = 0.35
# Number of Pairs: 6 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.01
# 2018-10-29: Short ESS and long PLD when Xt = 0.35
# 2018-12-28: Close pair when Xt = 0.38
# i = 13
# Number of Pairs: 40 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-10-13: Long DTE and short EVRG when Xt = 0.10
# 2017-05-22: Close pair when Xt = 0.15
# Number of Pairs: 14 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2017-07-31: Short FRT and long SPG when Xt = 0.27
# 2017-08-28: Close pair when Xt = 0.23
# Number of Pairs: 8 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.01
# 2017-09-01: Long WFC and short RF when Xt = 0.34
# 2018-01-03: Close pair when Xt = 0.40
# Number of Pairs: 6 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.01
# 2018-02-28: Long ED and short AEP when Xt = 0.12
# 2018-12-28: Close pair when Xt = 0.02
# i = 14
# Number of Pairs: 38 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-10-13: Short HES and long APA when Xt = 0.28
# 2015-10-28: Close pair when Xt = 0.23
# Number of Pairs: 35 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-29: Short MMC and long MS when Xt = 0.57
# 2015-11-10: Close pair when Xt = 0.53
# Number of Pairs: 27 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2015-11-11: Short HAL and long BKR when Xt = 0.14
# 2016-01-20: Close pair when Xt = 0.08
# Number of Pairs: 64 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.01
# 2016-01-21: Long TFC and short MET when Xt = 0.25
# 2016-02-05: Close pair when Xt = 0.31
# Number of Pairs: 36 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2016-02-08: Short HON and long USB when Xt = 0.38
# 2016-12-02: Close pair when Xt = 0.33
# Number of Pairs: 22 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.41 | Best Pair's p-value: 0.01
# 2016-12-09: Short PNW and long EIX when Xt = 0.26
# 2017-02-14: Close pair when Xt = 0.22
# Number of Pairs: 23 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.47 | Best Pair's p-value: 0.01
# 2017-02-16: Long SCHW and short BAC when Xt = 0.18
# 2017-06-21: Close pair when Xt = 0.28
# Number of Pairs: 15 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.01
# 2017-10-26: Short WEC and long LNT when Xt = 0.16
# 2018-03-23: Close pair when Xt = 0.14
# Number of Pairs: 5 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.01
# 2018-06-19: Long JPM and short RF when Xt = 0.34
# 2018-07-12: Close pair when Xt = 0.40
# Number of Pairs: 6 | Best Pair's Correlation: 0.93 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.00
# 2018-07-25: Short JPM and long BAC when Xt = 0.22
# 2018-12-28: Close pair when Xt = 0.25
# i = 15
# Number of Pairs: 42 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2015-10-14: Long ITW and short BLK when Xt = 0.33
# 2015-10-27: Close pair when Xt = 0.37
# Number of Pairs: 26 | Best Pair's Correlation: 0.88 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.01
# 2015-11-05: Long AEP and short DTE when Xt = 0.09
# 2015-12-15: Close pair when Xt = 0.13
# Number of Pairs: 38 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2016-01-08: Long STT and short MS when Xt = 0.18
# 2016-02-08: Close pair when Xt = 0.23
# Number of Pairs: 37 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.01
# 2016-02-09: Short BRO and long PRU when Xt = 0.64
# 2018-12-28: Close pair when Xt = 1.24
# i = 16
# Number of Pairs: 29 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2015-10-20: Short PLD and long WELL when Xt = 0.37
# 2016-01-15: Close pair when Xt = 0.31
# Number of Pairs: 61 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.17 | Best Pair's p-value: 0.00
# 2016-01-19: Long WFC and short ABT when Xt = 0.34
# 2016-01-28: Close pair when Xt = 0.41
# Number of Pairs: 41 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2016-01-29: Short AON and long MS when Xt = 0.58
# 2018-12-28: Close pair when Xt = 0.98
# i = 17
# Number of Pairs: 28 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-10-21: Long FITB and short C when Xt = 0.14
# 2015-11-10: Close pair when Xt = 0.21
# Number of Pairs: 17 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.01
# 2015-11-13: Long MMC and short RJF when Xt = 0.41
# 2016-01-13: Close pair when Xt = 0.46
# Number of Pairs: 53 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2016-01-14: Short KMB and long KDP when Xt = 0.31
# 2016-01-25: Close pair when Xt = 0.27
# Number of Pairs: 57 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2016-01-26: Short HON and long WFC when Xt = 0.37
# 2018-12-28: Close pair when Xt = 0.80
# i = 18
# Number of Pairs: 19 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-11-06: Long AON and short RJF when Xt = 0.40
# 2016-01-22: Close pair when Xt = 0.47
# Number of Pairs: 58 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-01-25: Short MMC and long TFC when Xt = 0.42
# 2018-12-28: Close pair when Xt = 0.71
# i = 19
# Number of Pairs: 15 | Best Pair's Correlation: 0.88 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.01
# 2015-11-10: Short XEL and long WEC when Xt = 0.24
# 2016-01-22: Close pair when Xt = 0.20
# Number of Pairs: 56 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2016-01-25: Short SO and long AEP when Xt = 0.26
# 2016-02-03: Close pair when Xt = 0.22
# Number of Pairs: 32 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-02-08: Short GPC and long TROW when Xt = 0.37
# 2017-07-06: Close pair when Xt = 0.32
# Number of Pairs: 14 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2017-10-30: Short DUK and long CMS when Xt = 0.18
# 2017-11-16: Close pair when Xt = 0.15
# Number of Pairs: 4 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.40 | Best Pair's p-value: 0.00
# 2018-07-26: Short DOC and long VTR when Xt = 0.20
# 2018-12-28: Close pair when Xt = 0.23
# i = 20
# Number of Pairs: 22 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2015-12-08: Long FITB and short SCHW when Xt = 0.27
# 2016-06-30: Close pair when Xt = 0.33
# Number of Pairs: 53 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.01
# 2016-07-12: Long USB and short JPM when Xt = 0.15
# 2016-08-23: Close pair when Xt = 0.19
# Number of Pairs: 26 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-08-24: Long AZO and short ORLY when Xt = 0.34
# 2016-11-22: Close pair when Xt = 0.39
# Number of Pairs: 19 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2016-11-23: Long XEL and short ATO when Xt = 0.18
# 2017-02-08: Close pair when Xt = 0.22
# Number of Pairs: 28 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.01
# 2017-02-13: Long ED and short EIX when Xt = 0.07
# 2017-05-17: Close pair when Xt = 0.11
# Number of Pairs: 13 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.42 | Best Pair's p-value: 0.00
# 2017-10-30: Short DUK and long PNW when Xt = 0.20
# 2017-12-08: Close pair when Xt = 0.17
# Number of Pairs: 5 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.01
# 2018-10-29: Long EOG and short MRO when Xt = 0.49
# 2018-12-12: Close pair when Xt = 0.59
# Number of Pairs: 13 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.45 | Best Pair's p-value: 0.01
# 2018-12-13: Short PNW and long NEE when Xt = 0.22
# 2018-12-28: Close pair when Xt = 0.20
# i = 21
# Number of Pairs: 31 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.01
# 2016-01-08: Long HBAN and short SCHW when Xt = 0.37
# 2016-11-18: Close pair when Xt = 0.43
# Number of Pairs: 21 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-11-21: Short D and long SO when Xt = 0.23
# 2018-04-06: Close pair when Xt = 0.19
# Number of Pairs: 14 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.41 | Best Pair's p-value: 0.01
# 2018-11-27: Short DUK and long AWK when Xt = 0.32
# 2018-12-28: Close pair when Xt = 0.32
# i = 22
# Number of Pairs: 54 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.00
# 2016-01-19: Short XEL and long AEE when Xt = 0.19
# 2016-11-09: Close pair when Xt = 0.15
# Number of Pairs: 25 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2016-11-14: Long GOOGL and short MSFT when Xt = 0.30
# 2017-01-23: Close pair when Xt = 0.36
# Number of Pairs: 24 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2017-01-27: Long C and short PRU when Xt = 0.09
# 2017-03-28: Close pair when Xt = 0.15
# Number of Pairs: 15 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2017-03-30: Long USB and short BAC when Xt = 0.56
# 2018-12-28: Close pair when Xt = 0.38
# i = 23
# Number of Pairs: 54 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2016-01-21: Long HBAN and short PRU when Xt = 0.25
# 2016-12-01: Close pair when Xt = 0.32
# Number of Pairs: 22 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2016-12-12: Short XEL and long NI when Xt = 0.41
# 2018-12-28: Close pair when Xt = 0.55
# i = 24
# Number of Pairs: 54 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.01
# 2016-01-25: Long PCG and short ES when Xt = 0.15
# 2016-02-03: Close pair when Xt = 0.20
# Number of Pairs: 30 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-02-08: Long PRU and short RF when Xt = 0.12
# 2016-03-01: Close pair when Xt = 0.17
# Number of Pairs: 29 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2016-03-03: Short MCO and long MS when Xt = 0.52
# 2016-10-31: Close pair when Xt = 0.45
# Number of Pairs: 25 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2016-11-01: Short AEE and long NI when Xt = 0.42
# 2018-12-28: Close pair when Xt = 0.69
# i = 25
# Number of Pairs: 50 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.46 | Best Pair's p-value: 0.00
# 2016-01-26: Short SO and long AEE when Xt = 0.29
# 2016-02-03: Close pair when Xt = 0.24
# Number of Pairs: 26 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.01
# 2016-03-28: Short XEL and long AWK when Xt = 0.42
# 2016-04-11: Close pair when Xt = 0.37
# Number of Pairs: 21 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-04-12: Long WFC and short PRU when Xt = 0.30
# 2018-12-28: Close pair when Xt = 0.19
# i = 26
# Number of Pairs: 43 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.42 | Best Pair's p-value: 0.00
# 2016-01-28: Short SO and long PPL when Xt = 0.31
# 2016-02-03: Close pair when Xt = 0.28
# Number of Pairs: 24 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2016-03-28: Long WFC and short NTRS when Xt = 0.24
# 2018-12-28: Close pair when Xt = -0.00
# i = 27
# Number of Pairs: 41 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.41 | Best Pair's p-value: 0.00
# 2016-01-28: Short DUK and long CNP when Xt = 0.38
# 2016-04-21: Close pair when Xt = 0.34
# Number of Pairs: 30 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2016-04-26: Long WFC and short RJF when Xt = 0.34
# 2018-12-28: Close pair when Xt = 0.03
# i = 28
# Number of Pairs: 40 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2016-01-28: Short SO and long PNW when Xt = 0.27
# 2016-02-03: Close pair when Xt = 0.22
# Number of Pairs: 24 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2016-03-29: Short PNW and long WEC when Xt = 0.18
# 2016-05-18: Close pair when Xt = 0.15
# Number of Pairs: 19 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.01
# 2016-05-25: Short BK and long PRU when Xt = 0.28
# 2016-07-21: Close pair when Xt = 0.24
# Number of Pairs: 37 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2016-08-03: Short AIG and long CBRE when Xt = 0.50
# 2017-02-15: Close pair when Xt = 0.45
# Number of Pairs: 21 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2017-02-16: Short EIX and long SRE when Xt = 0.39
# 2017-11-06: Close pair when Xt = 0.34
# Number of Pairs: 10 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2017-11-07: Short ES and long PNW when Xt = 0.09
# 2018-12-28: Close pair when Xt = 0.15
# i = 29
# Number of Pairs: 27 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2016-01-29: Short ITW and long TEL when Xt = 0.42
# 2018-12-28: Close pair when Xt = 0.63
# i = 30
# Number of Pairs: 23 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2016-06-01: Long ES and short AEE when Xt = 0.13
# 2018-12-28: Close pair when Xt = -0.01
# i = 31
# Number of Pairs: 24 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.01
# 2016-06-03: Short HAL and long HES when Xt = 0.41
# 2018-07-23: Close pair when Xt = 0.33
# Number of Pairs: 11 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2018-12-04: Short DUK and long AEP when Xt = 0.14
# 2018-12-28: Close pair when Xt = 0.13
# i = 32
# Number of Pairs: 22 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.01
# 2016-06-21: Short GL and long CMA when Xt = 0.58
# 2016-10-21: Close pair when Xt = 0.52
# Number of Pairs: 36 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.00
# 2016-10-24: Long MTB and short BK when Xt = 0.19
# 2016-11-08: Close pair when Xt = 0.23
# Number of Pairs: 22 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2016-11-14: Long DUK and short ATO when Xt = 0.25
# 2018-12-28: Close pair when Xt = 0.17
# i = 33
# Number of Pairs: 29 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2016-06-30: Short MTB and long PRU when Xt = 0.36
# 2016-07-20: Close pair when Xt = 0.29
# Number of Pairs: 31 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2016-08-08: Short SLB and long OXY when Xt = 0.28
# 2016-08-31: Close pair when Xt = 0.21
# Number of Pairs: 27 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-09-26: Long AEP and short CMS when Xt = 0.13
# 2017-06-08: Close pair when Xt = 0.16
# Number of Pairs: 8 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.01
# 2017-10-31: Short DUK and long ES when Xt = 0.18
# 2017-11-06: Close pair when Xt = 0.16
# i = 34
# Number of Pairs: 27 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-06-30: Short BRO and long AON when Xt = 0.25
# 2016-07-13: Close pair when Xt = 0.21
# Number of Pairs: 29 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2016-10-03: Long FRT and short KIM when Xt = 0.28
# 2016-12-30: Close pair when Xt = 0.32
# Number of Pairs: 26 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.01
# 2017-02-01: Long D and short PNW when Xt = 0.18
# 2018-02-05: Close pair when Xt = 0.23
# i = 35
# Number of Pairs: 48 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2016-10-19: Short GOOG and long MSFT when Xt = 0.42
# 2016-10-31: Close pair when Xt = 0.36
# Number of Pairs: 22 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.01
# 2016-11-02: Long VMC and short MLM when Xt = 0.25
# 2018-01-18: Close pair when Xt = 0.31
# i = 36
# Number of Pairs: 46 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.01
# 2016-10-19: Short PNW and long NI when Xt = 0.30
# 2018-06-13: Close pair when Xt = 0.26
# i = 37
# Number of Pairs: 34 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.00
# 2016-10-21: Short ROK and long TT when Xt = 0.32
# 2016-11-02: Close pair when Xt = 0.26
# Number of Pairs: 15 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.01
# 2016-11-21: Short FITB and long RJF when Xt = 0.20
# 2017-03-21: Close pair when Xt = 0.13
# i = 38
# Number of Pairs: 28 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.00
# 2016-10-25: Short KEY and long SCHW when Xt = 0.38
# 2018-05-07: Close pair when Xt = 0.29
# i = 39
# Number of Pairs: 25 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.01
# 2016-10-26: Short KEY and long RJF when Xt = 0.31
# 2018-10-22: Close pair when Xt = 0.23
# i = 40
# Number of Pairs: 23 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2016-10-28: Short RSG and long WM when Xt = 0.28
# 2018-12-28: Close pair when Xt = 0.40
# i = 41
# Number of Pairs: 18 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.01
# 2016-11-29: Short CMS and long NI when Xt = 0.39
# 2018-12-28: Close pair when Xt = 0.50
# i = 42
# Number of Pairs: 19 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.46 | Best Pair's p-value: 0.01
# 2016-12-28: Long RJF and short CMA when Xt = 0.18
# 2017-01-17: Close pair when Xt = 0.26
# Number of Pairs: 20 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2017-02-16: Long XEL and short EIX when Xt = 0.08
# 2017-05-01: Close pair when Xt = 0.11
# i = 43
# Number of Pairs: 11 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2017-02-28: Short JPM and long CMA when Xt = 0.47
# 2017-04-19: Close pair when Xt = 0.42
# i = 44
# Number of Pairs: 9 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2017-03-08: Short SRE and long NI when Xt = 0.42
# 2017-07-07: Close pair when Xt = 0.37
# i = 45

# %%
perf_df.to_csv('results/trade_record.csv')
