# %%
from Ornstein_Uhlenbeck import Ornstein_Uhlenbeck
from scipy.stats import norm
from statsmodels.tsa.stattools import adfuller
import backtrader as bt
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings

# %%
np.random.seed(4380)

# %%
np.seterr(all="ignore")
warnings.simplefilter('ignore', pd.errors.PerformanceWarning)

# %%
stock_list = pd.read_csv('data/stock_list.csv')['0']
obs = 252 # number of observations used by the model
cash = 100000000
commission = 0.004
stock_dict = {}
for stock in stock_list:
    stock_dict[stock] = pd.read_csv('data/stock/{}.csv'.format(stock), index_col='Date', parse_dates=['Date'])
    stock_dict[stock]['Close'] = stock_dict[stock]['Adj Close']
    stock_dict[stock]['Open'] = stock_dict[stock]['Adj Close'].shift(1)
    stock_dict[stock] = stock_dict[stock][stock_dict[stock].index < datetime.datetime(2019, 1, 1)].dropna()

# %%
class PandasData(bt.feeds.PandasData):
    lines = ('open', 'high', 'low', 'close', 'volume')
    params = (('datetime', None),
              ('open', 0),
              ('high', 1),
              ('low', 2),
              ('close', 3),
              ('adjclose', 4),
              ('volume', 5))

# %%
def get_hurst_exponent(time_series, max_lag=20):
    lags = range(2, max_lag)

    tau = [np.std(np.subtract(time_series[lag:], time_series[:-lag])) for lag in lags]
    
    reg = np.polyfit(np.log(lags), np.log(tau), 1)

    return reg[0]

# %%
perf_df = pd.DataFrame(columns=['Date', 'Spread Return', 'Position', 'Correlation', 'Hurst Exponent', 'ADF t-statistic', 'ADF p-value', 'mu', 'theta', 'sigma2'])

# %%
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.obs = obs
        self.n = 0 # number of days
        self.max_n = stock_dict[stock_list[0]].shape[0]
        self.pos = 0 # initial position
        self.holding_period = 0
        self.leverage = 3
        self.max_buy_portion = 0.9
        self.freeze = obs + np.random.randint(0, 252 // 12)
        
        # stocks selection
        self.req_corr = 0.7
        self.req_adf = 0.01
        self.req_hurst = 0.5
        
        # model settings
        self.model = None
        self.model_list = None
        self.idx_list = None
        self.a, self.b = None, None # index of Sta and Stb
        self.z = norm.ppf(0.99)
        
        # logging the process
        self.date_list = []
        self.Xt_list = []
        self.lb_list = []
        self.ub_list = []

    def signal_generation(self):
        if self.freeze > 0:
            self.freeze -= 1
            return 0
        
        if self.model_list is None or self.n >= self.max_n - 1:
            return 0
        
        if self.model is not None:
            self.Xt = self.model.alpha * self.Sta[-1] - self.model.beta * self.Stb[-1]

            if self.holding_period > 0:
                self.holding_period -= 1
                return self.pos
    
            if self.pos == 1:
                if self.Xt >= self.EX:
                    return 0
                else:
                    return 1
            elif self.pos == -1:
                if self.Xt <= self.EX:
                    return 0
                else:
                    return -1
        else: # to check is the model in the model_list can start the trade
            for i, model in enumerate(self.model_list):
                self.Sta = np.array(self.datas[self.idx_list[i][0]].close.get(size=self.obs))
                self.Stb = np.array(self.datas[self.idx_list[i][1]].close.get(size=self.obs))
                self.Xt = model.alpha * self.Sta[-1] - model.beta * self.Stb[-1]
                self.update_statistics(model)
                if self.Xt > self.EX + self.z * np.sqrt(self.VarX):
                    self.holding_period = 252 // 12
                    self.model = model
                    self.a, self.b = self.idx_list[i][0], self.idx_list[i][1]
                    self.corr = self.corr_list[i]
                    self.adf = self.adf_list[i]
                    self.hurst = self.hurst_list[i]
                    return -1
                elif self.Xt < self.EX - self.z * np.sqrt(self.VarX):
                    self.holding_period = 252 // 12
                    self.model = model
                    self.a, self.b = self.idx_list[i][0], self.idx_list[i][1]
                    self.corr = self.corr_list[i]
                    self.adf = self.adf_list[i]
                    self.hurst = self.hurst_list[i]
                    return 1
            return 0
    
    def update_statistics(self, model):
        self.EX = model.mu
        self.VarX = model.sigma2 / (2 * model.theta)
    
    def renew_model_list(self):
        stock_df = pd.DataFrame()
        for i, stock in enumerate(stock_list):
            stock_df[i] = np.array(self.datas[i].close.get(size=self.obs))
        corr = stock_df.pct_change().corr()
        model_list = []
        idx_list = []
        corr_list = []
        hurst_list = []
        adf_list = []
            
        for i in range(len(stock_list)):
            for j in range(i):
                if corr[i][j] > self.req_corr and np.random.rand() < 0.8: # quick test to choose the appropriate pairs
                    model1 = Ornstein_Uhlenbeck(stock_df[i].values, stock_df[j].values)
                    model2 = Ornstein_Uhlenbeck(stock_df[j].values, stock_df[i].values)
                    swap = 0
                    if model1.l is None and model2.l is None:
                        model = None
                    elif model1.l is None and model2.l is not None:
                        model = model2
                        swap = 1
                    elif model1.l is not None and model2.l is None:
                        model = model1
                    else:
                        if model1.l >= model2.l:
                            model = model1
                        else:
                            model = model2
                            swap = 1
                    
                    hurst = get_hurst_exponent(model.X)
                    adf = adfuller(model.X)
                    if hurst < self.req_hurst and adf[1] < self.req_adf:
                        model_list.append(model)
                        idx_list.append((i, j)) if swap == 0 else idx_list.append((j, i))
                        corr_list.append(corr[i][j])
                        hurst_list.append(hurst)
                        adf_list.append(adf)

        if len(model_list) > 0:
            rank_list = np.random.choice(np.arange(0, len(model_list)), len(model_list), replace=False)
            self.model_list = [model_list[i] for i in rank_list]
            self.idx_list = [idx_list[i] for i in rank_list]
            self.corr_list = [corr_list[i] for i in rank_list]
            self.hurst_list = [hurst_list[i] for i in rank_list]
            self.adf_list = [adf_list[i] for i in rank_list]
        
    def close_positions(self): # to close all existing positions
        self.close(data=self.datas[self.a])
        self.close(data=self.datas[self.b])
    
    def logging(self):
        self.date_list.append(self.data.datetime.date())
        if self.model is not None:
            self.Xt_list.append(self.Xt)
            self.lb_list.append(self.EX - self.z * np.sqrt(self.VarX))
            self.ub_list.append(self.EX + self.z * np.sqrt(self.VarX))
        else:
            self.Xt_list.append(0)
            self.lb_list.append(0)
            self.ub_list.append(0)

        if self.date_list[-1] == self.last_day:
            plt.figure(figsize=(10, 6))
            plt.plot(self.date_list, self.lb_list, label='Lower Bound')
            plt.plot(self.date_list, self.ub_list, label='Upper Bound')
            plt.plot(self.date_list, self.Xt_list, label=r'$X_t$')
            plt.legend()
    
    def start(self):
        self.last_day = self.data.datetime.date(-1)  # Get the last available date
        
    def next(self): 
        self.n += 1
        if self.n >= self.obs:
            if self.model_list is None and self.freeze == 0:
                self.renew_model_list()
            if self.model is not None:
                self.Sta = np.array(self.datas[self.a].close.get(size=self.obs))
                self.Stb = np.array(self.datas[self.b].close.get(size=self.obs))
            
        self.signal = self.signal_generation()
        
        if self.signal != 0 and self.pos == 0:
            print('Number of Pairs: {} | Best Pair\'s Correlation: {:.2f} | Best Pair\'s Hurst Exponent: {:.2f} | Best Pair\'s p-value: {:.2f}'.format(len(self.model_list), self.corr, self.hurst, self.adf[1]))
    
        if self.signal == 1:
            if self.pos == 0:
                k = self.leverage / (self.Sta[-1] * self.model.alpha + self.model.beta * self.Stb[-1])
                k = np.min([k, 1 / (self.model.alpha * self.Sta[-1])])
                self.sell(data=self.datas[self.b], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.beta * k)
                self.buy(data=self.datas[self.a], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.alpha * k)
                self.Xs = self.Xt
                print("{}: Long {} and short {} when Xt = {:.2f}".format(self.data.datetime.date(), stock_list.loc[self.a], stock_list.loc[self.b], self.Xt))
                
        elif self.signal == -1:
            if self.pos == 0:
                k = self.leverage / (self.Sta[-1] * self.model.alpha + self.model.beta * self.Stb[-1])
                k = np.min([k, 1 / (self.model.beta * self.Stb[-1])])
                self.sell(data=self.datas[self.a], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.alpha * k)
                self.buy(data=self.datas[self.b], size=self.max_buy_portion * cerebro.broker.get_value() * self.model.beta * k)
                self.Xs = self.Xt
                print("{}: Short {} and long {} when Xt = {:.2f}".format(self.data.datetime.date(), stock_list.loc[self.a], stock_list.loc[self.b], self.Xt))
                
        else: # self.signal == 0
            if self.pos != 0:
                self.close_positions()
                perf_df.loc[len(perf_df)] = [self.data.datetime.date(), np.log(self.Xt / self.Xs) * self.pos, self.pos, self.corr, self.hurst, self.adf[0], self.adf[1], self.model.mu, self.model.theta, self.model.sigma2]
                self.model = None
                self.freeze = np.random.randint(0, 252 // 12)
                print("{}: Close pair when Xt = {:.2f}".format(self.data.datetime.date(), self.Xt))
                
        self.pos = self.signal
        
        if self.n >= self.obs:
            # self.logging()
            
            if self.pos == 0:
                self.model_list = None

# %%
for i in range(30):
    print('i = {}'.format(i))
    # backtest settings
    cerebro = bt.Cerebro()
    
    data_feed_dict = {}
    for stock in stock_list:
        data_feed_dict[stock] = PandasData(dataname=stock_dict[stock], name=stock)
        cerebro.adddata(data_feed_dict[stock])
    
    cerebro.addstrategy(MyStrategy)
    cerebro.broker.setcash(cash)
    cerebro.broker.setcommission(commission=commission)
    # Run the backtest
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    results = cerebro.run()
    pyfolio_analyzer = results[0].analyzers.pyfolio
    returns, positions, transactions, gross_lev = pyfolio_analyzer.get_pf_items()
# Out:
# i = 0
# Number of Pairs: 21 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-01-12: Long C and short MS when Xt = 0.25
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 29 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 20 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.01
# 2015-05-13: Short MCK and long CAH when Xt = 0.33
# 2015-08-06: Close pair when Xt = 0.27
# Number of Pairs: 17 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-08-17: Short D and long DTE when Xt = 0.24
# 2015-09-17: Close pair when Xt = 0.21
# Number of Pairs: 30 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.00
# 2015-09-21: Short SPXX and long EVT when Xt = 0.27
# 2015-10-21: Close pair when Xt = 0.23
# Number of Pairs: 29 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-11-02: Long D and short DTE when Xt = 0.18
# 2018-12-28: Close pair when Xt = -0.04
# i = 1
# Number of Pairs: 15 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2015-01-07: Long C and short MS when Xt = 0.24
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-04-02: Short EIX and long ED when Xt = 0.16
# 2015-05-05: Close pair when Xt = 0.11
# Number of Pairs: 23 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 24 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-20: Short NRO and long VNO when Xt = 0.43
# 2015-08-24: Close pair when Xt = 0.39
# Number of Pairs: 28 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.00
# 2015-09-21: Short SPXX and long EVT when Xt = 0.27
# 2015-10-21: Close pair when Xt = 0.23
# Number of Pairs: 44 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-10-22: Short MMC and long MS when Xt = 0.60
# 2018-12-28: Close pair when Xt = 1.01
# i = 2
# Number of Pairs: 15 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 31 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 23 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-05-11: Short MCK and long CAH when Xt = 0.32
# 2015-08-06: Close pair when Xt = 0.28
# Number of Pairs: 20 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-08-18: Short D and long DTE when Xt = 0.24
# 2015-09-18: Close pair when Xt = 0.20
# Number of Pairs: 26 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.00
# 2015-09-21: Short SPXX and long EVT when Xt = 0.27
# 2015-10-21: Close pair when Xt = 0.23
# Number of Pairs: 32 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-11-02: Long D and short DTE when Xt = 0.18
# 2018-12-28: Close pair when Xt = -0.04
# i = 3
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 31 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.01
# 2015-04-09: Short JPM and long C when Xt = 0.24
# 2018-12-28: Close pair when Xt = 0.98
# i = 4
# Number of Pairs: 16 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 30 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-04-08: Long CB and short HIG when Xt = 0.41
# 2015-12-17: Close pair when Xt = 0.44
# Number of Pairs: 24 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.00
# 2015-12-21: Short ETJ and long EXG when Xt = 0.50
# 2016-01-25: Close pair when Xt = 0.47
# Number of Pairs: 25 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.20 | Best Pair's p-value: 0.00
# 2016-02-12: Long NTRS and short RF when Xt = 0.19
# 2016-03-16: Close pair when Xt = 0.27
# Number of Pairs: 28 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2016-03-31: Long WFC and short PRU when Xt = 0.34
# 2018-12-28: Close pair when Xt = 0.22
# i = 5
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 31 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-04-02: Short EIX and long ED when Xt = 0.16
# 2015-05-05: Close pair when Xt = 0.11
# Number of Pairs: 20 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2015-05-14: Short USA and long R when Xt = 0.63
# 2015-08-24: Close pair when Xt = 0.56
# Number of Pairs: 30 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.00
# 2015-09-21: Short SPXX and long EVT when Xt = 0.27
# 2015-10-21: Close pair when Xt = 0.23
# Number of Pairs: 35 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-12-07: Long C and short SCHW when Xt = 0.28
# 2017-05-24: Close pair when Xt = 0.32
# Number of Pairs: 20 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2017-06-20: Short PPL and long EIX when Xt = 0.26
# 2017-11-03: Close pair when Xt = 0.21
# Number of Pairs: 7 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.44 | Best Pair's p-value: 0.01
# 2017-11-15: Long HBAN and short RF when Xt = 0.17
# 2018-11-14: Close pair when Xt = 0.23
# Number of Pairs: 10 | Best Pair's Correlation: 0.88 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2018-12-04: Short DUK and long AEP when Xt = 0.10
# 2018-12-28: Close pair when Xt = 0.09
# i = 6
# Number of Pairs: 16 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 20 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 22 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-20: Short NRO and long VNO when Xt = 0.43
# 2015-08-24: Close pair when Xt = 0.39
# Number of Pairs: 38 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.01
# 2015-09-09: Long WFC and short SWK when Xt = 0.28
# 2018-12-28: Close pair when Xt = 0.02
# i = 7
# Number of Pairs: 15 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 34 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-04-02: Short EIX and long ED when Xt = 0.16
# 2015-05-05: Close pair when Xt = 0.11
# Number of Pairs: 23 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 17 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-08-18: Short D and long DTE when Xt = 0.24
# 2015-09-18: Close pair when Xt = 0.20
# Number of Pairs: 38 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-02: Long D and short DTE when Xt = 0.18
# 2018-12-28: Close pair when Xt = -0.05
# i = 8
# Number of Pairs: 13 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 20 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 24 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-20: Short NRO and long VNO when Xt = 0.43
# 2015-08-24: Close pair when Xt = 0.39
# Number of Pairs: 35 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-09-14: Long UNM and short FITB when Xt = 0.24
# 2015-10-20: Close pair when Xt = 0.30
# Number of Pairs: 40 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-10-23: Short MMC and long MS when Xt = 0.60
# 2018-12-28: Close pair when Xt = 1.01
# i = 9
# Number of Pairs: 15 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-01-13: Long C and short MS when Xt = 0.25
# 2015-03-02: Close pair when Xt = 0.31
# Number of Pairs: 29 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 19 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2015-05-12: Short MCK and long CAH when Xt = 0.32
# 2015-08-06: Close pair when Xt = 0.27
# Number of Pairs: 26 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-08-25: Short FEI            and long FEN when Xt = 0.23
# 2015-10-01: Close pair when Xt = 0.19
# Number of Pairs: 51 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-12: Short ASG and long ABT when Xt = 0.62
# 2015-11-12: Close pair when Xt = 0.58
# Number of Pairs: 38 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.01
# 2015-12-08: Long WFC and short SCHW when Xt = 0.45
# 2016-01-28: Close pair when Xt = 0.50
# Number of Pairs: 35 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.01
# 2016-02-02: Short AON and long MS when Xt = 0.57
# 2018-12-28: Close pair when Xt = 0.98
# i = 10
# Number of Pairs: 10 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-02-06: Long XEL and short CMS when Xt = 0.12
# 2015-03-11: Close pair when Xt = 0.15
# Number of Pairs: 27 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 21 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 22 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-20: Short NRO and long VNO when Xt = 0.43
# 2015-08-24: Close pair when Xt = 0.39
# Number of Pairs: 30 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-09-04: Long ITW and short MMM when Xt = 0.17
# 2015-11-30: Close pair when Xt = 0.22
# Number of Pairs: 34 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.01
# 2015-12-24: Long HAL and short HP when Xt = 0.32
# 2016-05-02: Close pair when Xt = 0.42
# Number of Pairs: 30 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.01
# 2016-05-31: Short BTO and long SCHW when Xt = 0.46
# 2018-12-18: Close pair when Xt = 0.38
# Number of Pairs: 19 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.18 | Best Pair's p-value: 0.00
# 2018-12-26: Short FEN and long FEI            when Xt = 0.29
# 2018-12-28: Close pair when Xt = 0.29
# i = 11
# Number of Pairs: 14 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2015-01-07: Long C and short MS when Xt = 0.24
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 29 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 23 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2015-05-06: Long NRO and short PSA when Xt = 0.35
# 2016-07-26: Close pair when Xt = 0.39
# Number of Pairs: 29 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2016-08-24: Long AZO and short ORLY when Xt = 0.34
# 2016-11-22: Close pair when Xt = 0.39
# Number of Pairs: 32 | Best Pair's Correlation: 0.94 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-12-05: Long XEL and short CMS when Xt = 0.06
# 2017-01-18: Close pair when Xt = 0.09
# Number of Pairs: 26 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2017-02-09: Long DUK and short EIX when Xt = 0.13
# 2017-05-17: Close pair when Xt = 0.18
# Number of Pairs: 19 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2017-06-19: Short PPL and long EIX when Xt = 0.27
# 2017-11-03: Close pair when Xt = 0.21
# Number of Pairs: 5 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.20 | Best Pair's p-value: 0.00
# 2017-12-21: Long CMS and short AEP when Xt = 0.21
# 2018-04-24: Close pair when Xt = 0.24
# Number of Pairs: 9 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.00
# 2018-06-18: Long DTE and short XEL when Xt = 0.12
# 2018-07-19: Close pair when Xt = 0.17
# Number of Pairs: 5 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.01
# 2018-08-17: Long MXF and short MXE when Xt = 0.11
# 2018-12-28: Close pair when Xt = 0.05
# i = 12
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 34 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-04-06: Long CB and short HIG when Xt = 0.40
# 2015-12-17: Close pair when Xt = 0.43
# Number of Pairs: 50 | Best Pair's Correlation: 0.88 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2016-01-19: Short XEL and long AEE when Xt = 0.19
# 2016-11-09: Close pair when Xt = 0.15
# Number of Pairs: 29 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-11-17: Short JPM and long BTO when Xt = 0.34
# 2018-12-28: Close pair when Xt = 0.77
# i = 13
# Number of Pairs: 13 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 35 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-04-06: Long CB and short HIG when Xt = 0.40
# 2015-12-17: Close pair when Xt = 0.43
# Number of Pairs: 46 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.00
# 2015-12-30: Long HAL and short HP when Xt = 0.33
# 2016-05-02: Close pair when Xt = 0.42
# Number of Pairs: 32 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-05-26: Short NTRS and long PRU when Xt = 0.23
# 2016-07-11: Close pair when Xt = 0.18
# Number of Pairs: 58 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.01
# 2016-07-15: Short MCO and long ZION when Xt = 0.43
# 2016-10-19: Close pair when Xt = 0.35
# Number of Pairs: 42 | Best Pair's Correlation: 0.86 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2016-10-24: Short JPM and long FHN when Xt = 0.23
# 2016-11-23: Close pair when Xt = 0.19
# Number of Pairs: 32 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-12-19: Short AEE and long PNW when Xt = 0.17
# 2017-04-06: Close pair when Xt = 0.14
# Number of Pairs: 14 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2017-05-17: Long HBAN and short RF when Xt = 0.17
# 2017-06-19: Close pair when Xt = 0.24
# Number of Pairs: 15 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.00
# 2017-07-06: Short EQT and long RRC when Xt = 0.49
# 2018-03-28: Close pair when Xt = 0.42
# Number of Pairs: 11 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2018-05-01: Long GS and short MS when Xt = 0.19
# 2018-08-20: Close pair when Xt = 0.24
# Number of Pairs: 5 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2018-10-29: Long EOG and short MRO when Xt = 0.49
# 2018-12-12: Close pair when Xt = 0.59
# Number of Pairs: 12 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.00
# 2018-12-20: Long BTO and short CMA when Xt = 0.17
# 2018-12-28: Close pair when Xt = 0.17
# i = 14
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 34 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 28 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2015-05-06: Long NRO and short PSA when Xt = 0.35
# 2016-07-26: Close pair when Xt = 0.39
# Number of Pairs: 51 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-08-16: Long AZO and short ORLY when Xt = 0.30
# 2016-11-22: Close pair when Xt = 0.33
# Number of Pairs: 37 | Best Pair's Correlation: 0.94 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2016-11-28: Long XEL and short CMS when Xt = 0.06
# 2016-12-29: Close pair when Xt = 0.08
# Number of Pairs: 26 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2017-01-30: Long C and short PRU when Xt = 0.10
# 2017-03-29: Close pair when Xt = 0.16
# Number of Pairs: 18 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2017-04-21: Short FEN and long SRV when Xt = 0.35
# 2018-03-23: Close pair when Xt = 0.31
# Number of Pairs: 7 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.01
# 2018-05-02: Long GS and short MS when Xt = 0.17
# 2018-08-20: Close pair when Xt = 0.24
# Number of Pairs: 5 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.41 | Best Pair's p-value: 0.01
# 2018-11-02: Long EOG and short MRO when Xt = 0.47
# 2018-12-12: Close pair when Xt = 0.56
# Number of Pairs: 10 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.00
# 2018-12-20: Long BTO and short CMA when Xt = 0.17
# 2018-12-28: Close pair when Xt = 0.17
# i = 15
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 33 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-04-02: Short EIX and long ED when Xt = 0.16
# 2015-05-05: Close pair when Xt = 0.11
# Number of Pairs: 21 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 19 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2015-08-12: Short D and long EIX when Xt = 0.43
# 2015-09-14: Close pair when Xt = 0.37
# Number of Pairs: 47 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-10-08: Short NRO and long VNO when Xt = 0.43
# 2015-12-14: Close pair when Xt = 0.38
# Number of Pairs: 47 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2016-01-08: Long GPC and short BLK when Xt = 0.31
# 2016-02-10: Close pair when Xt = 0.40
# Number of Pairs: 25 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.21 | Best Pair's p-value: 0.00
# 2016-02-12: Short WFC and long PRU when Xt = 0.41
# 2016-03-16: Close pair when Xt = 0.36
# Number of Pairs: 27 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2016-04-01: Long WFC and short NTRS when Xt = 0.24
# 2018-12-28: Close pair when Xt = 0.03
# i = 16
# Number of Pairs: 11 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-02-06: Long XEL and short CMS when Xt = 0.12
# 2015-03-11: Close pair when Xt = 0.15
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 16 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2015-05-12: Short MCK and long CAH when Xt = 0.32
# 2015-08-06: Close pair when Xt = 0.27
# Number of Pairs: 13 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-08-17: Short D and long DTE when Xt = 0.24
# 2015-09-17: Close pair when Xt = 0.21
# Number of Pairs: 40 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-02: Long D and short DTE when Xt = 0.18
# 2018-12-28: Close pair when Xt = -0.05
# i = 17
# Number of Pairs: 15 | Best Pair's Correlation: 0.78 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2015-01-07: Long FEI            and short FEN when Xt = 0.19
# 2015-02-24: Close pair when Xt = 0.22
# Number of Pairs: 28 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 18 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.01
# 2015-05-13: Short MCK and long CAH when Xt = 0.33
# 2015-08-06: Close pair when Xt = 0.27
# Number of Pairs: 22 | Best Pair's Correlation: 0.83 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-08-21: Short D and long DTE when Xt = 0.24
# 2015-09-23: Close pair when Xt = 0.20
# Number of Pairs: 47 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-12: Short ASG and long ABT when Xt = 0.62
# 2015-11-12: Close pair when Xt = 0.58
# Number of Pairs: 35 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-12-07: Long C and short SCHW when Xt = 0.28
# 2017-05-24: Close pair when Xt = 0.32
# Number of Pairs: 18 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2017-06-19: Short PPL and long EIX when Xt = 0.27
# 2017-11-03: Close pair when Xt = 0.21
# Number of Pairs: 5 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.20 | Best Pair's p-value: 0.00
# 2017-12-21: Long CMS and short AEP when Xt = 0.21
# 2018-04-24: Close pair when Xt = 0.24
# Number of Pairs: 9 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.00
# 2018-06-18: Long DTE and short XEL when Xt = 0.12
# 2018-07-19: Close pair when Xt = 0.17
# Number of Pairs: 4 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.01
# 2018-08-17: Long MXF and short MXE when Xt = 0.11
# 2018-12-28: Close pair when Xt = 0.05
# i = 18
# Number of Pairs: 21 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-01-14: Long C and short MS when Xt = 0.24
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 32 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 17 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 21 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2015-08-12: Short D and long EIX when Xt = 0.43
# 2015-09-14: Close pair when Xt = 0.37
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-09-17: Short SPXX and long USA when Xt = 0.38
# 2016-01-19: Close pair when Xt = 0.34
# Number of Pairs: 44 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.22 | Best Pair's p-value: 0.01
# 2016-01-28: Long STT and short MS when Xt = 0.16
# 2016-03-03: Close pair when Xt = 0.22
# Number of Pairs: 35 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2016-03-29: Long WFC and short NTRS when Xt = 0.24
# 2018-12-28: Close pair when Xt = 0.04
# i = 19
# Number of Pairs: 12 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-02-06: Long XEL and short CMS when Xt = 0.12
# 2015-03-11: Close pair when Xt = 0.15
# Number of Pairs: 33 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 20 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-04: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 20 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-07-27: Short PPL and long EXC when Xt = 0.47
# 2017-12-19: Close pair when Xt = 0.40
# Number of Pairs: 7 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.01
# 2018-01-30: Long PFG and short LNC when Xt = 0.39
# 2018-12-28: Close pair when Xt = 0.30
# i = 20
# Number of Pairs: 15 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 29 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.01
# 2015-04-09: Short JPM and long C when Xt = 0.24
# 2018-12-28: Close pair when Xt = 0.98
# i = 21
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 22 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 18 | Best Pair's Correlation: 0.70 | Best Pair's Hurst Exponent: 0.34 | Best Pair's p-value: 0.01
# 2015-08-12: Short D and long EIX when Xt = 0.43
# 2015-09-14: Close pair when Xt = 0.37
# Number of Pairs: 46 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.01
# 2015-10-06: Short SPXX and long USA when Xt = 0.38
# 2016-01-19: Close pair when Xt = 0.34
# Number of Pairs: 41 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.01
# 2016-02-02: Short HON and long USB when Xt = 0.39
# 2016-12-06: Close pair when Xt = 0.33
# Number of Pairs: 31 | Best Pair's Correlation: 0.89 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2017-01-05: Long USB and short JPM when Xt = 0.29
# 2017-02-07: Close pair when Xt = 0.34
# Number of Pairs: 16 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2017-03-31: Long USB and short BAC when Xt = 0.55
# 2018-12-28: Close pair when Xt = 0.40
# i = 22
# Number of Pairs: 16 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 32 | Best Pair's Correlation: 0.81 | Best Pair's Hurst Exponent: 0.28 | Best Pair's p-value: 0.00
# 2015-04-07: Short JPM and long C when Xt = 0.24
# 2018-12-28: Close pair when Xt = 0.98
# i = 23
# Number of Pairs: 21 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-01-13: Long C and short MS when Xt = 0.25
# 2015-03-02: Close pair when Xt = 0.31
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 24 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.37 | Best Pair's p-value: 0.00
# 2015-05-06: Long NRO and short PSA when Xt = 0.35
# 2016-07-26: Close pair when Xt = 0.39
# Number of Pairs: 46 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-08-16: Long AZO and short ORLY when Xt = 0.30
# 2016-11-22: Close pair when Xt = 0.33
# Number of Pairs: 34 | Best Pair's Correlation: 0.84 | Best Pair's Hurst Exponent: 0.25 | Best Pair's p-value: 0.00
# 2016-12-16: Short AEE and long PNW when Xt = 0.17
# 2017-04-06: Close pair when Xt = 0.13
# Number of Pairs: 16 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.00
# 2017-04-21: Short FEN and long SRV when Xt = 0.35
# 2018-03-23: Close pair when Xt = 0.31
# Number of Pairs: 9 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2018-05-01: Long GS and short MS when Xt = 0.19
# 2018-08-20: Close pair when Xt = 0.24
# Number of Pairs: 7 | Best Pair's Correlation: 0.87 | Best Pair's Hurst Exponent: 0.16 | Best Pair's p-value: 0.00
# 2018-11-02: Short AIV and long AVB when Xt = 0.16
# 2018-12-28: Close pair when Xt = 0.16
# i = 24
# Number of Pairs: 13 | Best Pair's Correlation: 0.91 | Best Pair's Hurst Exponent: 0.38 | Best Pair's p-value: 0.01
# 2015-02-06: Long XEL and short CMS when Xt = 0.12
# 2015-03-11: Close pair when Xt = 0.15
# Number of Pairs: 28 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 18 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 21 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.01
# 2015-07-28: Short PPL and long EXC when Xt = 0.47
# 2017-12-19: Close pair when Xt = 0.41
# Number of Pairs: 7 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.13 | Best Pair's p-value: 0.00
# 2018-01-17: Long FEI            and short FEN when Xt = 0.25
# 2018-12-28: Close pair when Xt = 0.09
# i = 25
# Number of Pairs: 14 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 28 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-04-02: Short EIX and long ED when Xt = 0.16
# 2015-05-05: Close pair when Xt = 0.11
# Number of Pairs: 19 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.26 | Best Pair's p-value: 0.01
# 2015-05-13: Short MCK and long CAH when Xt = 0.33
# 2015-08-06: Close pair when Xt = 0.27
# Number of Pairs: 22 | Best Pair's Correlation: 0.73 | Best Pair's Hurst Exponent: 0.20 | Best Pair's p-value: 0.00
# 2015-08-21: Long EVT and short HON when Xt = 0.50
# 2015-10-16: Close pair when Xt = 0.54
# Number of Pairs: 37 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.29 | Best Pair's p-value: 0.00
# 2015-10-28: Short MMC and long MS when Xt = 0.59
# 2018-12-28: Close pair when Xt = 0.99
# i = 26
# Number of Pairs: 21 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-01-13: Long C and short STT when Xt = 0.21
# 2015-02-27: Close pair when Xt = 0.26
# Number of Pairs: 30 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 21 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2015-05-08: Short MCK and long CAH when Xt = 0.33
# 2015-08-06: Close pair when Xt = 0.29
# Number of Pairs: 40 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.45 | Best Pair's p-value: 0.01
# 2015-09-02: Long IVZ and short A when Xt = 0.23
# 2018-12-28: Close pair when Xt = -0.68
# i = 27
# Number of Pairs: 22 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-01-12: Long C and short MS when Xt = 0.25
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 27 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 23 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 24 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.01
# 2015-07-28: Short PPL and long EXC when Xt = 0.47
# 2017-12-19: Close pair when Xt = 0.41
# Number of Pairs: 6 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.01
# 2018-01-30: Long PFG and short LNC when Xt = 0.39
# 2018-12-28: Close pair when Xt = 0.30
# i = 28
# Number of Pairs: 17 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2015-02-05: Short D and long AEE when Xt = 0.39
# 2015-03-10: Close pair when Xt = 0.32
# Number of Pairs: 32 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 21 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.23 | Best Pair's p-value: 0.00
# 2015-05-08: Short MCK and long CAH when Xt = 0.33
# 2015-08-06: Close pair when Xt = 0.29
# Number of Pairs: 38 | Best Pair's Correlation: 0.74 | Best Pair's Hurst Exponent: 0.17 | Best Pair's p-value: 0.01
# 2015-09-01: Long EVT and short HON when Xt = 0.45
# 2015-10-16: Close pair when Xt = 0.50
# Number of Pairs: 39 | Best Pair's Correlation: 0.77 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2015-10-21: Short MMC and long MS when Xt = 0.59
# 2018-12-28: Close pair when Xt = 1.02
# i = 29
# Number of Pairs: 24 | Best Pair's Correlation: 0.72 | Best Pair's Hurst Exponent: 0.31 | Best Pair's p-value: 0.00
# 2015-01-14: Long C and short MS when Xt = 0.24
# 2015-03-02: Close pair when Xt = 0.30
# Number of Pairs: 29 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.33 | Best Pair's p-value: 0.00
# 2015-03-30: Short EIX and long ED when Xt = 0.17
# 2015-04-30: Close pair when Xt = 0.12
# Number of Pairs: 21 | Best Pair's Correlation: 0.76 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-06-03: Long XEL and short PCG when Xt = 0.26
# 2015-07-07: Close pair when Xt = 0.31
# Number of Pairs: 25 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.36 | Best Pair's p-value: 0.01
# 2015-07-20: Short NRO and long VNO when Xt = 0.43
# 2015-08-24: Close pair when Xt = 0.39
# Number of Pairs: 36 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.27 | Best Pair's p-value: 0.00
# 2015-08-27: Short FEI            and long FEN when Xt = 0.24
# 2015-10-01: Close pair when Xt = 0.18
# Number of Pairs: 49 | Best Pair's Correlation: 0.79 | Best Pair's Hurst Exponent: 0.19 | Best Pair's p-value: 0.01
# 2015-10-06: Short SPXX and long USA when Xt = 0.38
# 2016-01-19: Close pair when Xt = 0.34
# Number of Pairs: 46 | Best Pair's Correlation: 0.80 | Best Pair's Hurst Exponent: 0.32 | Best Pair's p-value: 0.00
# 2016-01-22: Long HBAN and short PRU when Xt = 0.25
# 2016-12-01: Close pair when Xt = 0.32
# Number of Pairs: 31 | Best Pair's Correlation: 0.82 | Best Pair's Hurst Exponent: 0.24 | Best Pair's p-value: 0.00
# 2016-12-29: Long NTG and short SRV when Xt = 0.12
# 2017-03-31: Close pair when Xt = 0.20
# Number of Pairs: 16 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.30 | Best Pair's p-value: 0.00
# 2017-05-17: Long HBAN and short RF when Xt = 0.17
# 2017-06-19: Close pair when Xt = 0.24
# Number of Pairs: 15 | Best Pair's Correlation: 0.85 | Best Pair's Hurst Exponent: 0.35 | Best Pair's p-value: 0.01
# 2017-07-13: Long USB and short MTB when Xt = 0.38
# 2017-08-14: Close pair when Xt = 0.44
# Number of Pairs: 13 | Best Pair's Correlation: 0.75 | Best Pair's Hurst Exponent: 0.39 | Best Pair's p-value: 0.00
# 2017-09-01: Long WFC and short RF when Xt = 0.35
# 2017-12-21: Close pair when Xt = 0.41
# Number of Pairs: 5 | Best Pair's Correlation: 0.71 | Best Pair's Hurst Exponent: 0.43 | Best Pair's p-value: 0.01
# 2018-01-30: Long PFG and short LNC when Xt = 0.39
# 2018-12-28: Close pair when Xt = 0.30

# %%
perf_df.to_csv('trade_record.csv')
